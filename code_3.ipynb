# %%
DeepRetro_path = '/root/workspace/DFS/DeepRetro'

# %%
# %cd DeepRetro/
# Out:
# /root/workspace/DFS/DeepRetro

# %%
# !uv pip install aizynthfinder
# !mkdir -p aizynthfinder/models/USPTO
# !python -m aizynthfinder.tools.download_public_data aizynthfinder/models/USPTO/
# Out:
# uspto_model.onnx: 100%|███████████████████| 91.5M/91.5M [00:29<00:00, 3.08MB/s]
# uspto_templates.csv.gz: 3.31MB [00:03, 905kB/s]
# uspto_ringbreaker_model.onnx: 100%|███████| 15.0M/15.0M [00:13<00:00, 1.15MB/s]
# uspto_ringbreaker_templates.csv.gz: 374kB [00:00, 735kB/s]
# zinc_stock.hdf5: 100%|██████████████████████| 663M/663M [00:24<00:00, 27.6MB/s]
# uspto_filter_model.onnx: 100%|████████████| 16.8M/16.8M [00:13<00:00, 1.22MB/s]
# Configuration file written to config.yml

# %%
# !python "{DeepRetro_path}/scripts/run_batch.py"  \
--sheet-url "https://docs.google.com/spreadsheets/d/1fxosGkIKTBw5OTau8h1a1KAmQC4Jt6hCep6YQyrCp1Q/export?format=csv"   \
--molecules "{DeepRetro_path}/molecules_trial.txt"  \
--out "batch_output"   \
--solve-mode single_step_agent   \
--tool-backend structured   \
--model claude-sonnet-5 \
--az-model '/root/workspace/DFS/aizynthfinder/models'  \
--top-k 2
# Out:
# This module requires PyTorch to be installed.
# Skipped loading some Pytorch utilities, missing a dependency. No module named 'torch'
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# Skipped loading some PyTorch models, missing a dependency. No module named 'torch'
# No module named 'torch'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch'
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'torch'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'
# Skipped loading some PyTorch models, missing a dependency. No module named 'tensorflow'
# ...

# %%
# !uv pip install litellm -q

# %%
# !uv pip install "langfuse<3" -q

# %%
# !uv pip install deepchem
# Out:
# Using Python 3.11.15 environment at: /venv/vllm
# Checked 1 package in 4ms

# %%
# !uv pip install xgboost -q

# %%
# !uv pip install tenacity
# Out:
# Using Python 3.11.15 environment at: /venv/vllm
# Resolved 1 package in 86ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)-------------------     0 B/28.25 KiB
# ⠙ Preparing packages... (0/1)m-------------- 16.00 KiB/28.25 KiB
# ⠙ Preparing packages... (0/1)---------- 28.25 KiB/28.25 KiB
# Prepared 1 package in 13ms
# Installed 1 package in 32ms
#  + tenacity==9.1.4

# %%
# !uv pip install scikit-learn -q

# %%
# !uv pip install structlog -q
# Out:
# Using Python 3.11.15 environment at: /venv/vllm
# Resolved 1 package in 51ms
# Installed 1 package in 2ms
#  + structlog==26.1.0

# %%
# %pwd
# Out:
# '/kaggle/working/DFS'

# %%
# %cd DeepRetro/
# Out:
# /root/workspace/DFS/DeepRetro

# %%
# !python --version
# Out:
# Python 3.12.13

# %%
# !uv pip install -e .
# Out:
# Using Python 3.11.15 environment at: /venv/vllm
# ⠙ pydantic-core==2.41.5
# Resolved 122 packages in 293ms5b0
#    Building deepretro @ file:///root/workspace/DFS/DeepRetro
#    Building deepretro @ file:///root/workspace/DFS/DeepRetro
# ⠙ Preparing packages... (0/25)
#    Building deepretro @ file:///root/workspace/DFS/DeepRetro7 KiB
# ⠙ Preparing packages... (0/25)
#    Building deepretro @ file:///root/workspace/DFS/DeepRetro7 KiB
# ⠙ Preparing packages... (0/25)
# opentelemetry-proto  ------------------------------     0 B/70.78 KiB
#    Building deepretro @ file:///root/workspace/DFS/DeepRetro7 KiB
# ⠙ Preparing packages... (0/25)
# opentelemetry-proto  ------------------------------     0 B/70.78 KiB
#    Building deepretro @ file:///root/workspace/DFS/DeepRetro7 KiB
# ⠙ Preparing packages... (0/25)
# opentelemetry-proto  ------------------------------     0 B/70.78 KiB
#    Building deepretro @ file:///root/workspace/DFS/DeepRetro7 KiB
# ⠙ Preparing packages... (0/25)
# ...

# %%
# %cd DeepRetro
# Out:
# /root/workspace/DFS/DeepRetro

# %%
# !pip install rdkit -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 50.1 MB/s eta 0:00:00:00:0100:01

# %%
# !vllm serve allenai/Olmo-3-7B-Instruct \
--dtype bfloat16 --max-model-len 8192 --enable-prefix-caching
# Out:
# (APIServer pid=32977) INFO 09-23 16:01:24 [api_utils.py:339]
# (APIServer pid=32977) INFO 09-23 16:01:24 [api_utils.py:339]        █     █     █▄   ▄█
# (APIServer pid=32977) INFO 09-23 16:01:24 [api_utils.py:339]  ▄▄ ▄█ █     █     █ ▀▄▀ █  version 0.25.1
# (APIServer pid=32977) INFO 09-23 16:01:24 [api_utils.py:339]   █▄█▀ █     █     █     █  model   allenai/Olmo-3-7B-Instruct
# (APIServer pid=32977) INFO 09-23 16:01:24 [api_utils.py:339]    ▀▀  ▀▀▀▀▀ ▀▀▀▀▀ ▀     ▀
# (APIServer pid=32977) INFO 09-23 16:01:24 [api_utils.py:339]
# (APIServer pid=32977) INFO 09-23 16:01:24 [api_utils.py:273] non-default args: {'model_tag': 'allenai/Olmo-3-7B-Instruct', 'model': 'allenai/Olmo-3-7B-Instruct', 'dtype': 'bfloat16', 'max_model_len': 8192, 'enable_prefix_caching': True}
# (APIServer pid=32977) WARNING 09-23 16:01:24 [envs.py:2041] Unknown vLLM environment variable detected: VLLM_BUILD_URL
# ...
