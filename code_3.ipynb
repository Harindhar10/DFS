# %%
DeepRetro_path = '/kaggle/working/DFS/DeepRetro'

# %%
# !python "{DeepRetro_path}/scripts/run_batch.py"  \
--sheet-url "https://docs.google.com/spreadsheets/d/1fxosGkIKTBw5OTau8h1a1KAmQC4Jt6hCep6YQyrCp1Q/export?format=csv"   \
--molecules "{DeepRetro_path}/molecules.txt"  \
--out "batch_output"   \
--solve-mode single_step_agent   \
--tool-backend structured   \
--model anthropic/claude-sonnet \
--az-model ./  \
--top-k 5

# %%
# %pwd
# Out:
# '/kaggle/working/DFS'

# %%
# %cd DeepRetro/
# Out:
# /kaggle/working/DFS/DeepRetro
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !python --version
# Out:
# Python 3.12.13

# %%
# !uv pip install -e . -q
# Out:
#   × No solution found when resolving dependencies:
#   ╰─▶ Because all versions of rdkit-pypi have no wheels with a matching Python
#       ABI tag (e.g., `cp312`) and deepretro==0.0.1 depends on rdkit-pypi, we
#       can conclude that deepretro==0.0.1 cannot be used.
#       And because only deepretro==0.0.1 is available and you require
#       deepretro, we can conclude that your requirements are unsatisfiable.
#
#       hint: Pre-releases are available for `rdkit-pypi` in the requested
#       range (e.g., 2023.3.1b1), but pre-releases weren't enabled (try:
#       `--prerelease=allow`)
#
#       hint: You require CPython 3.12 (`cp312`), but we only found wheels for
#       `rdkit-pypi` (v2022.9.5) with the following Python ABI tags: `cp37m`,
#       `cp38`, `cp39`, `cp310`, `cp311`

# %%
# !pip install rdkit -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 50.1 MB/s eta 0:00:00:00:0100:01
